# %% [markdown]
# # Elevation<br>
# ## Purpose
# Evaluates the effect of elevation in a countries ability to win medals
# ## Datasets
# <b>Elevation.csv</b>

# %% [markdown]
# Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import os.path
from sklearn.linear_model import LinearRegression 
import math

# %% [markdown]
# Loads in dataset

# %%
filepath = '../../data/analysis/elevation_data.csv'
if not os.path.exists( filepath ):
    print("Missing dataset file")
else:
    df = pd.read_csv(filepath , encoding = "ISO-8859-1")
    print("File Read")
# Out:
# File Read

# %%
df.head()
# Out:
#    Unnamed: 0  Year Host_Country Host_City  Summer  Winter  Total_Males  \
# 0           0  1960          ITA      Rome    True   False         4727
# 1           1  1960          ITA      Rome    True   False         4727
# 2           2  1960          ITA      Rome    True   False         4727
# 3           3  1960          ITA      Rome    True   False         4727
# 4           4  1960          ITA      Rome    True   False         4727
#
#    Total_Females  Total_Athletes Discipline       ...        CO2_Emissions  \
# 0            611            5338    Sailing       ...            48815.104
# 1            611            5338     Boxing       ...            48815.104
# 2            611            5338   Swimming       ...            88202.351
# 3            611            5338   Eventing       ...            88202.351
# 4            611            5338   Swimming       ...            88202.351
#
#   Methane_Emissions Nitrous_Oxide_Emisions  Total_Emissions  \
# 0               NaN                    NaN        48815.104
# 1               NaN                    NaN        48815.104
# 2               NaN                    NaN        88202.351
# 3               NaN                    NaN        88202.351
# 4               NaN                    NaN        88202.351
#
#    Emmisions_per_Capita  Code  Lowest_Point  Highest_Point  Elevation_Range  \
# 0                   NaN   ARG        -105.0         6962.0           7067.0
# 1                   NaN   ARG        -105.0         6962.0           7067.0
# 2                   NaN   AUS         -15.0         2228.0           2243.0
# 3                   NaN   AUS         -15.0         2228.0           2243.0
# 4                   NaN   AUS         -15.0         2228.0           2243.0
#
#    Education_Index
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# Some of the columns in the dataframa are not useful for reaserach into elevation

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Host_Country', 'Host_City', 'Summer', 'Winter',
#        'Total_Males', 'Total_Females', 'Total_Athletes', 'Discipline', 'Sport',
#        'Ath_Name', 'Gender', 'Home_Adv', 'Gold', 'Silver', 'Bronze',
#        'Total_Medals', 'Ath_Rating', 'Ath_Rank', 'NOC', 'NOC_Males_Sent',
#        'NOC_Females_Sent', 'NOC_Total_Sent', 'NOC_Gold', 'NOC_Silver',
#        'NOC_Bronze', 'NOC_Total_Medals', 'NOC_Rating', 'NOC_Rank', 'Country',
#        'Population', 'Males', 'Females', 'Life_Expectancy', 'GDP', 'Region',
#        'Elevation', 'Area_SqKM', 'Centroid_Longitude', 'Centroid_Latitude',
#        'Population_Density', 'CO2_Emissions', 'Methane_Emissions',
#        'Nitrous_Oxide_Emisions', 'Total_Emissions', 'Emmisions_per_Capita',
#        'Code', 'Lowest_Point', 'Highest_Point', 'Elevation_Range',
#        'Education_Index'],
#       dtype='object')

# %% [markdown]
# The following columns we decided were valid to out study

# %%
df = df[['Year', 'Host_Country', 'Host_City', 'Summer', 'Winter',
       'Total_Males', 'Total_Females', 'Total_Athletes', 'Discipline', 'Sport',
       'Ath_Name', 'Gender', 'Home_Adv', 'Gold', 'Silver', 'Bronze',
       'Total_Medals', 'Ath_Rating', 'Ath_Rank', 'NOC', 'NOC_Males_Sent',
       'NOC_Females_Sent', 'NOC_Total_Sent', 'Country', 'Region',
       'Elevation', 'Area_SqKM', 'Centroid_Longitude', 'Centroid_Latitude',
        'Lowest_Point', 'Highest_Point', 'Elevation_Range']]
df.head()
# Out:
#    Year Host_Country Host_City  Summer  Winter  Total_Males  Total_Females  \
# 0  1960          ITA      Rome    True   False         4727            611
# 1  1960          ITA      Rome    True   False         4727            611
# 2  1960          ITA      Rome    True   False         4727            611
# 3  1960          ITA      Rome    True   False         4727            611
# 4  1960          ITA      Rome    True   False         4727            611
#
#    Total_Athletes Discipline       Sport       ...       NOC_Total_Sent  \
# 0            5338    Sailing     Sailing       ...                 91.0
# 1            5338     Boxing      Boxing       ...                 91.0
# 2            5338   Swimming    Aquatics       ...                194.0
# 3            5338   Eventing  Equestrian       ...                194.0
# 4            5338   Swimming    Aquatics       ...                194.0
#
#      Country         Region  Elevation  Area_SqKM  Centroid_Longitude  \
# 0  Argentina  South America   595.6200  2775401.0           -64.92097
# 1  Argentina  South America   595.6200  2775401.0           -64.92097
# 2  Australia        Oceania   272.4731  7662592.0           134.61310
# 3  Australia        Oceania   272.4731  7662592.0           134.61310
# 4  Australia        Oceania   272.4731  7662592.0           134.61310
#
#    Centroid_Latitude  Lowest_Point  Highest_Point Elevation_Range
# 0          -35.38706        -105.0         6962.0          7067.0
# 1          -35.38706        -105.0         6962.0          7067.0
# 2          -25.84766         -15.0         2228.0          2243.0
# 3          -25.84766         -15.0         2228.0          2243.0
# 4          -25.84766         -15.0         2228.0          2243.0
#
# [5 rows x 32 columns]

# %% [markdown]
# Checks to see what null values exist for elevation

# %%
df[df.Elevation.isnull()]
# Out:
#        Year Host_Country  Host_City  Summer  Winter  Total_Males  \
# 1811   1972          DEU     Munich    True   False         6075
# 3048   1980          RUS     Moscow    True   False         4064
# 4200   1988          KOR      Seoul    True   False         6197
# 5273   1992          ESP  Barcelone    True   False         6652
# 5274   1992          ESP  Barcelone    True   False         6652
# 5275   1992          ESP  Barcelone    True   False         6652
# 11369  2016          BRA        Rio    True   False         6173
# 11370  2016          BRA        Rio    True   False         6173
#
#        Total_Females  Total_Athletes             Discipline          Sport  \
# 1811            1059            7134          Weightlifting  Weightlifting
# 3048            1115            5179  Wrestling Greco-Roman      Wrestling
# 4200            2194            8391                Sailing        Sailing
# 5273            2704            9356               Shooting       Shooting
# 5274            2704            9356               Shooting       Shooting
# 5275            2704            9356               Shooting       Shooting
# 11369           5055           11228               Shooting       Shooting
# 11370           5055           11228               Shooting       Shooting
#
#             ...       NOC_Total_Sent Country  Region  Elevation  Area_SqKM  \
# 1811        ...                 19.0     NaN     NaN        NaN        NaN
# 3048        ...                 16.0     NaN     NaN        NaN        NaN
# 4200        ...                  2.0     NaN     NaN        NaN        NaN
# 5273        ...                 59.0     NaN     NaN        NaN        NaN
# 5274        ...                 59.0     NaN     NaN        NaN        NaN
# 5275        ...                 59.0     NaN     NaN        NaN        NaN
# 11369       ...                  9.0     NaN     NaN        NaN        NaN
# 11370       ...                  9.0     NaN     NaN        NaN        NaN
#
#        Centroid_Longitude  Centroid_Latitude  Lowest_Point  Highest_Point  \
# 1811                  NaN                NaN           NaN            NaN
# 3048                  NaN                NaN           NaN            NaN
# 4200                  NaN                NaN           NaN            NaN
# 5273                  NaN                NaN           NaN            NaN
# 5274                  NaN                NaN           NaN            NaN
# 5275                  NaN                NaN           NaN            NaN
# 11369                 NaN                NaN           NaN            NaN
# 11370                 NaN                NaN           NaN            NaN
#
#       Elevation_Range
# 1811              NaN
# 3048              NaN
# 4200              NaN
# 5273              NaN
# 5274              NaN
# 5275              NaN
# 11369             NaN
# 11370             NaN
#
# [8 rows x 32 columns]

# %%
len(df[df.Elevation.isnull()])
# Out:
# 8

# %% [markdown]
# The data above relates to eight medal winning athletes from NOCs for whom we were unable to obtain data on, we have amde the decision to remove these lines as they will skew our results

# %%
df = df[df.Elevation.notnull()]
len(df)
# Out:
# 11814

# %% [markdown]
# ## Group the data by Country
# To be able to examine what effect elevation has we had to group thhe data by country

# %%
countryDF = df.groupby(['Country','Elevation','Lowest_Point','Highest_Point','Elevation_Range','Sport'])\
            ['Gold', 'Silver','Bronze', 'Total_Medals','Ath_Rating'].sum()

countryDF = countryDF.reset_index()
countryDF.head()
# Out:
#        Country  Elevation  Lowest_Point  Highest_Point  Elevation_Range  \
# 0  Afghanistan  1884.7100         258.0         7492.0           7234.0
# 1      Algeria   572.8028         -40.0         2908.0           2948.0
# 2      Algeria   572.8028         -40.0         2908.0           2948.0
# 3      Algeria   572.8028         -40.0         2908.0           2948.0
# 4    Argentina   595.6200        -105.0         6962.0           7067.0
#
#        Sport  Gold  Silver  Bronze  Total_Medals  Ath_Rating
# 0  Taekwondo     0       0       2             2           2
# 1  Athletics     4       3       2             9          20
# 2     Boxing     1       0       5             6           8
# 3       Judo     0       1       1             2           3
# 4   Aquatics     0       0       1             1           1

# %% [markdown]
# ## Finding Medal Share

# %% [markdown]
# The first step is to establish how many medals have been awarded in each games

# %%
totMeds = df.groupby(['Sport'])[['Gold','Total_Medals','Ath_Rating']].sum()
totMeds.head(40)
# Out:
#                    Gold  Total_Medals  Ath_Rating
# Sport
# Aquatics            693          1911        3918
# Archery              48           131         267
# Athletics           649          1888        3812
# Badminton            29            94         184
# Baseball              5            15          30
# Basketball           20            71         136
# Biathlon             97           274         563
# Bobsleigh            34           109         215
# Boxing              172           687        1202
# Canoe               226           651        1320
# Curling               9            29          57
# Cycling             184           539        1083
# Equestrian          136           361         753
# Fencing             181           489        1004
# Football             21            64         127
# Golf                  2             6          12
# Gymnastics          309           811        1688
# Handball             21            66         130
# Hockey               25            70         143
# Ice Hockey           17            53         105
# Judo                137           545         955
# Luge                 38           116         228
# Modern Pentathlon    42           108         227
# Rowing              174           529        1054
# Rugby                 2             6          12
# Sailing             118           356         710
# Shooting            167           505        1010
# Skating             265           767        1549
# Skiing              426          1212        2470
# Softball              4            12          24
# Table Tennis         23            77         149
# Taekwondo            40           144         264
# Tennis               28           100         188
# Triathlon            10            30          60
# Volleyball           37           111         221
# Weightlifting       159           481         959
# Wrestling           276           880        1708

# %% [markdown]
# ### Gold Share
# Evaluating what fraction of the gold medals were awarded to a given country in a given event

# %%
countryDF['Gold_Share'] = countryDF.apply(lambda x: x.Gold/totMeds.loc[x.Sport].Gold, axis=1 )
countryDF.head()
# Out:
#        Country  Elevation  Lowest_Point  Highest_Point  Elevation_Range  \
# 0  Afghanistan  1884.7100         258.0         7492.0           7234.0
# 1      Algeria   572.8028         -40.0         2908.0           2948.0
# 2      Algeria   572.8028         -40.0         2908.0           2948.0
# 3      Algeria   572.8028         -40.0         2908.0           2948.0
# 4    Argentina   595.6200        -105.0         6962.0           7067.0
#
#        Sport  Gold  Silver  Bronze  Total_Medals  Ath_Rating  Gold_Share
# 0  Taekwondo     0       0       2             2           2    0.000000
# 1  Athletics     4       3       2             9          20    0.006163
# 2     Boxing     1       0       5             6           8    0.005814
# 3       Judo     0       1       1             2           3    0.000000
# 4   Aquatics     0       0       1             1           1    0.000000

# %% [markdown]
# ### Medal Share
# Evaluating what fraction of the medals were awarded to a given country in a given event

# %%
countryDF['Medal_Share'] = countryDF.apply(lambda x: x.Total_Medals/totMeds.loc[x.Sport].Total_Medals, axis=1 )
countryDF.head()
# Out:
#        Country  Elevation  Lowest_Point  Highest_Point  Elevation_Range  \
# 0  Afghanistan  1884.7100         258.0         7492.0           7234.0
# 1      Algeria   572.8028         -40.0         2908.0           2948.0
# 2      Algeria   572.8028         -40.0         2908.0           2948.0
# 3      Algeria   572.8028         -40.0         2908.0           2948.0
# 4    Argentina   595.6200        -105.0         6962.0           7067.0
#
#        Sport  Gold  Silver  Bronze  Total_Medals  Ath_Rating  Gold_Share  \
# 0  Taekwondo     0       0       2             2           2    0.000000
# 1  Athletics     4       3       2             9          20    0.006163
# 2     Boxing     1       0       5             6           8    0.005814
# 3       Judo     0       1       1             2           3    0.000000
# 4   Aquatics     0       0       1             1           1    0.000000
#
#    Medal_Share
# 0     0.013889
# 1     0.004767
# 2     0.008734
# 3     0.003670
# 4     0.000523

# %% [markdown]
# ### Rating Share
# Evaluating what fraction of the rating were awarded to a given country in a given event

# %%
countryDF['Rating_Share'] = countryDF.apply(lambda x: x.Ath_Rating/totMeds.loc[x.Sport].Ath_Rating, axis=1 )
countryDF.head()
# Out:
#        Country  Elevation  Lowest_Point  Highest_Point  Elevation_Range  \
# 0  Afghanistan  1884.7100         258.0         7492.0           7234.0
# 1      Algeria   572.8028         -40.0         2908.0           2948.0
# 2      Algeria   572.8028         -40.0         2908.0           2948.0
# 3      Algeria   572.8028         -40.0         2908.0           2948.0
# 4    Argentina   595.6200        -105.0         6962.0           7067.0
#
#        Sport  Gold  Silver  Bronze  Total_Medals  Ath_Rating  Gold_Share  \
# 0  Taekwondo     0       0       2             2           2    0.000000
# 1  Athletics     4       3       2             9          20    0.006163
# 2     Boxing     1       0       5             6           8    0.005814
# 3       Judo     0       1       1             2           3    0.000000
# 4   Aquatics     0       0       1             1           1    0.000000
#
#    Medal_Share  Rating_Share
# 0     0.013889      0.007576
# 1     0.004767      0.005247
# 2     0.008734      0.006656
# 3     0.003670      0.003141
# 4     0.000523      0.000255

# %% [markdown]
# # Normalising the data

# %%
def minMaxNorm(mn,mx,val):
    return (val-mn)/(mx-mn)

# %% [markdown]
# ### Gold_Share

# %%
mn = countryDF['Gold_Share'].min()
mx = countryDF['Gold_Share'].max()
countryDF['norm_Gold_Share'] = countryDF['Gold_Share'].apply(lambda x: minMaxNorm(mn,mx,x))
countryDF.head()
# Out:
#        Country  Elevation  Lowest_Point  Highest_Point  Elevation_Range  \
# 0  Afghanistan  1884.7100         258.0         7492.0           7234.0
# 1      Algeria   572.8028         -40.0         2908.0           2948.0
# 2      Algeria   572.8028         -40.0         2908.0           2948.0
# 3      Algeria   572.8028         -40.0         2908.0           2948.0
# 4    Argentina   595.6200        -105.0         6962.0           7067.0
#
#        Sport  Gold  Silver  Bronze  Total_Medals  Ath_Rating  Gold_Share  \
# 0  Taekwondo     0       0       2             2           2    0.000000
# 1  Athletics     4       3       2             9          20    0.006163
# 2     Boxing     1       0       5             6           8    0.005814
# 3       Judo     0       1       1             2           3    0.000000
# 4   Aquatics     0       0       1             1           1    0.000000
#
#    Medal_Share  Rating_Share  norm_Gold_Share
# 0     0.013889      0.007576         0.000000
# 1     0.004767      0.005247         0.007088
# 2     0.008734      0.006656         0.006686
# 3     0.003670      0.003141         0.000000
# 4     0.000523      0.000255         0.000000

# %% [markdown]
# ### Medal_Share

# %%
mn = countryDF['Medal_Share'].min()
mx = countryDF['Medal_Share'].max()
countryDF['norm_Medal_Share'] = countryDF['Medal_Share'].apply(lambda x: minMaxNorm(mn,mx,x))
countryDF.head()
# Out:
#        Country  Elevation  Lowest_Point  Highest_Point  Elevation_Range  \
# 0  Afghanistan  1884.7100         258.0         7492.0           7234.0
# 1      Algeria   572.8028         -40.0         2908.0           2948.0
# 2      Algeria   572.8028         -40.0         2908.0           2948.0
# 3      Algeria   572.8028         -40.0         2908.0           2948.0
# 4    Argentina   595.6200        -105.0         6962.0           7067.0
#
#        Sport  Gold  Silver  Bronze  Total_Medals  Ath_Rating  Gold_Share  \
# 0  Taekwondo     0       0       2             2           2    0.000000
# 1  Athletics     4       3       2             9          20    0.006163
# 2     Boxing     1       0       5             6           8    0.005814
# 3       Judo     0       1       1             2           3    0.000000
# 4   Aquatics     0       0       1             1           1    0.000000
#
#    Medal_Share  Rating_Share  norm_Gold_Share  norm_Medal_Share
# 0     0.013889      0.007576         0.000000          0.030305
# 1     0.004767      0.005247         0.007088          0.009622
# 2     0.008734      0.006656         0.006686          0.018616
# 3     0.003670      0.003141         0.000000          0.007134
# 4     0.000523      0.000255         0.000000          0.000000

# %% [markdown]
# ### Rating_Share

# %%
mn = countryDF['Rating_Share'].min()
mx = countryDF['Rating_Share'].max()
countryDF['norm_Rating_Share'] = countryDF['Rating_Share'].apply(lambda x: minMaxNorm(mn,mx,x))
countryDF.head()
# Out:
#        Country  Elevation  Lowest_Point  Highest_Point  Elevation_Range  \
# 0  Afghanistan  1884.7100         258.0         7492.0           7234.0
# 1      Algeria   572.8028         -40.0         2908.0           2948.0
# 2      Algeria   572.8028         -40.0         2908.0           2948.0
# 3      Algeria   572.8028         -40.0         2908.0           2948.0
# 4    Argentina   595.6200        -105.0         6962.0           7067.0
#
#        Sport  Gold  Silver  Bronze  Total_Medals  Ath_Rating  Gold_Share  \
# 0  Taekwondo     0       0       2             2           2    0.000000
# 1  Athletics     4       3       2             9          20    0.006163
# 2     Boxing     1       0       5             6           8    0.005814
# 3       Judo     0       1       1             2           3    0.000000
# 4   Aquatics     0       0       1             1           1    0.000000
#
#    Medal_Share  Rating_Share  norm_Gold_Share  norm_Medal_Share  \
# 0     0.013889      0.007576         0.000000          0.030305
# 1     0.004767      0.005247         0.007088          0.009622
# 2     0.008734      0.006656         0.006686          0.018616
# 3     0.003670      0.003141         0.000000          0.007134
# 4     0.000523      0.000255         0.000000          0.000000
#
#    norm_Rating_Share
# 0           0.012991
# 1           0.008858
# 2           0.011358
# 3           0.005122
# 4           0.000000

# %% [markdown]
# ### Avearge Elevation

# %%
mn = countryDF['Elevation'].min()
mx = countryDF['Elevation'].max()
countryDF['norm_Elevation'] = countryDF['Elevation'].apply(lambda x: minMaxNorm(mn,mx,x))
countryDF.head()
# Out:
#        Country  Elevation  Lowest_Point  Highest_Point  Elevation_Range  \
# 0  Afghanistan  1884.7100         258.0         7492.0           7234.0
# 1      Algeria   572.8028         -40.0         2908.0           2948.0
# 2      Algeria   572.8028         -40.0         2908.0           2948.0
# 3      Algeria   572.8028         -40.0         2908.0           2948.0
# 4    Argentina   595.6200        -105.0         6962.0           7067.0
#
#        Sport  Gold  Silver  Bronze  Total_Medals  Ath_Rating  Gold_Share  \
# 0  Taekwondo     0       0       2             2           2    0.000000
# 1  Athletics     4       3       2             9          20    0.006163
# 2     Boxing     1       0       5             6           8    0.005814
# 3       Judo     0       1       1             2           3    0.000000
# 4   Aquatics     0       0       1             1           1    0.000000
#
#    Medal_Share  Rating_Share  norm_Gold_Share  norm_Medal_Share  \
# 0     0.013889      0.007576         0.000000          0.030305
# 1     0.004767      0.005247         0.007088          0.009622
# 2     0.008734      0.006656         0.006686          0.018616
# 3     0.003670      0.003141         0.000000          0.007134
# 4     0.000523      0.000255         0.000000          0.000000
#
#    norm_Rating_Share  norm_Elevation
# 0           0.012991        0.591575
# 1           0.008858        0.179792
# 2           0.011358        0.179792
# 3           0.005122        0.179792
# 4           0.000000        0.186954

# %% [markdown]
# # Output

# %%
countryDF.to_csv('../../data/final/Education.csv', index=False)
